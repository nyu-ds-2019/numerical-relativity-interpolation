# %%
import h5py
import numpy as np

# %%
hf = h5py.File('../data/Proca_fiducial_scaled_cropped.hdf5', 'r')

# %%
hf.keys()
# Out:
# <KeysViewHDF5 ['Train']>

# %%
x = hf.get('Train').get('input')
y = hf.get('Train').get('target')

# %%
inputs = np.array(x)
outputs = np.array(y)

# %%
inputs.shape, outputs.shape
# Out:
# ((407, 2, 72, 72, 72), (407, 1, 72, 72, 72))

# %%
inputs.mean(), inputs.argmax(), inputs.min()
# Out:
# (0.02135032497171533, 2050451, 0.0)

# %%
test = 255 * (inputs - inputs.min()) / (inputs.max() - inputs.min())

# %%
import cv2
from PIL import Image

# %%
im_pil = Image.fromarray(inputs[0, 0, 0, :, :], 'L')
im_pil
# Out:
# <PIL.Image.Image image mode=L size=72x72 at 0x7FDA03CFE950>

# %%
im_pil = Image.fromarray(test[0, 0, 0, :, :], 'L')
im_pil
# Out:
# <PIL.Image.Image image mode=L size=72x72 at 0x7FDA03D03590>

# %%
im_pil = Image.fromarray(outputs[0, 0, 0, :, :], 'L')
im_pil
# Out:
# <PIL.Image.Image image mode=L size=72x72 at 0x7F9FBDA1A710>

# %%
im_pil = Image.fromarray(inputs[0, 1, 0, :, :], 'L')
im_pil
# Out:
# <PIL.Image.Image image mode=L size=72x72 at 0x7F9FBDA228D0>

# %%
Image.fromarray(inputs[305, 0, :, :, 0], 'L')
# Out:
# <PIL.Image.Image image mode=L size=72x72 at 0x7F9FBDA04B90>
